# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bank-dataset/PNB_5Y.csv
# /kaggle/input/bank-dataset/UNIONBANK_5Y.csv
# /kaggle/input/bank-dataset/BOI_5Y.csv
# /kaggle/input/bank-dataset/SBIN_5Y.csv

# %%
df = pd.read_csv("../input/bank-dataset/BOI_5Y.csv")
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-06-06  197.449997  202.600006  197.100006  198.899994  195.314117
# 1  2016-06-07  200.449997  211.149994  200.149994  210.149994  206.361298
# 2  2016-06-08  210.149994  211.899994  207.550003  210.699997  206.901398
# 3  2016-06-09  210.000000  212.800003  208.300003  209.949997  206.164902
# 4  2016-06-10  209.350006  211.500000  205.300003  205.949997  202.237015
#
#        Volume
# 0  23623536.0
# 1  66063192.0
# 2  35163093.0
# 3  27858182.0
# 4  25598224.0

# %%
close = df["Close"]
close.shape
# Out:
# (1234,)

# %%
close
# Out:
# 0       198.899994
# 1       210.149994
# 2       210.699997
# 3       209.949997
# 4       205.949997
#            ...
# 1229    424.350006
# 1230    432.549988
# 1231    437.250000
# 1232    439.649994
# 1233    433.600006
# Name: Close, Length: 1234, dtype: float64

# %%
type(close)
# Out:
# pandas.core.series.Series

# %%
close = close.dropna()
close.shape
# Out:
# (1232,)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
tmp = scaler.fit(np.array(close).reshape(-1,1))
new_df = scaler.transform(np.array(close).reshape(-1,1))

 
print(new_df)
# Out:
# [[0.16637808]
#  [0.20533238]
#  [0.20723682]
#  ...
#  [0.99168977]
#  [1.        ]
#  [0.97905129]]

# %%
training_size=int(len(new_df)*0.67)
test_size=len(new_df)-training_size
train_data,test_data=new_df[0:training_size,:],new_df[training_size:len(new_df),:1]

print(train_data.shape)
print(test_data.shape)
# Out:
# (825, 1)
# (407, 1)

# %%
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX), np.array(dataY)

# %%
time_step=100
X_train, Y_train = create_dataset(train_data, time_step)
X_test, Y_test = create_dataset(test_data, time_step)
print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape)
#print(X_train, Y_train)
# Out:
# (724, 100) (724,) (306, 100) (306,)

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
print(X_train.shape, X_test.shape)
#print(X_train, Y_train)
# Out:
# (724, 100, 1) (306, 100, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM

model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(X_train.shape[1],X_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# dropout (Dropout)            (None, 100, 50)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 50)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,Y_train,validation_data=(X_test, Y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 9s 341ms/step - loss: 0.1226 - val_loss: 0.0241
# Epoch 2/100
# 12/12 [==============================] - 2s 210ms/step - loss: 0.0081 - val_loss: 0.0259
# Epoch 3/100
# 12/12 [==============================] - 2s 210ms/step - loss: 0.0064 - val_loss: 0.0257
# Epoch 4/100
# 12/12 [==============================] - 2s 205ms/step - loss: 0.0050 - val_loss: 0.0235
# Epoch 5/100
# 12/12 [==============================] - 2s 204ms/step - loss: 0.0041 - val_loss: 0.0218
# Epoch 6/100
# 12/12 [==============================] - 2s 208ms/step - loss: 0.0040 - val_loss: 0.0200
# Epoch 7/100
# 12/12 [==============================] - 2s 205ms/step - loss: 0.0038 - val_loss: 0.0182
# Epoch 8/100
# 12/12 [==============================] - 2s 209ms/step - loss: 0.0039 - val_loss: 0.0163
# Epoch 9/100
# 12/12 [==============================] - 3s 221ms/step - loss: 0.0033 - val_loss: 0.0146
# Epoch 10/100
# 12/12 [==============================] - 2s 207ms/step - loss: 0.0034 - val_loss: 0.0130
# Epoch 11/100
# 12/12 [==============================] - 2s 205ms/step - loss: 0.0030 - val_loss: 0.0116
# Epoch 12/100
# 12/12 [==============================] - 2s 208ms/step - loss: 0.0031 - val_loss: 0.0109
# Epoch 13/100
# 12/12 [==============================] - 2s 208ms/step - loss: 0.0031 - val_loss: 0.0104
# Epoch 14/100
# 12/12 [==============================] - 2s 206ms/step - loss: 0.0032 - val_loss: 0.0101
# Epoch 15/100
# 12/12 [==============================] - 2s 207ms/step - loss: 0.0029 - val_loss: 0.0099
# Epoch 16/100
# 12/12 [==============================] - 2s 205ms/step - loss: 0.0026 - val_loss: 0.0094
# Epoch 17/100
# 12/12 [==============================] - 3s 211ms/step - loss: 0.0027 - val_loss: 0.0087
# Epoch 18/100
# 12/12 [==============================] - 2s 210ms/step - loss: 0.0026 - val_loss: 0.0085
# Epoch 19/100
# 12/12 [==============================] - 2s 210ms/step - loss: 0.0027 - val_loss: 0.0079
# Epoch 20/100
# 12/12 [==============================] - 2s 208ms/step - loss: 0.0026 - val_loss: 0.0080
# Epoch 21/100
# 12/12 [==============================] - 3s 211ms/step - loss: 0.0025 - val_loss: 0.0079
# Epoch 22/100
# 12/12 [==============================] - 3s 224ms/step - loss: 0.0024 - val_loss: 0.0079
# Epoch 23/100
# 12/12 [==============================] - 2s 202ms/step - loss: 0.0023 - val_loss: 0.0078
# Epoch 24/100
# 12/12 [==============================] - 2s 203ms/step - loss: 0.0026 - val_loss: 0.0073
# Epoch 25/100
# 12/12 [==============================] - 2s 208ms/step - loss: 0.0025 - val_loss: 0.0072
# Epoch 26/100
# 12/12 [==============================] - 2s 205ms/step - loss: 0.0022 - val_loss: 0.0067
# Epoch 27/100
# 12/12 [==============================] - 2s 209ms/step - loss: 0.0024 - val_loss: 0.0074
# Epoch 28/100
# 12/12 [==============================] - 2s 208ms/step - loss: 0.0020 - val_loss: 0.0067
# Epoch 29/100
# 12/12 [==============================] - 2s 205ms/step - loss: 0.0022 - val_loss: 0.0065
# Epoch 30/100
# 12/12 [==============================] - 2s 208ms/step - loss: 0.0024 - val_loss: 0.0064
# Epoch 31/100
# 12/12 [==============================] - 2s 205ms/step - loss: 0.0023 - val_loss: 0.0072
# Epoch 32/100
# 12/12 [==============================] - 2s 203ms/step - loss: 0.0026 - val_loss: 0.0068
# Epoch 33/100
# 12/12 [==============================] - 2s 203ms/step - loss: 0.0025 - val_loss: 0.0073
# Epoch 34/100
# 12/12 [==============================] - 2s 209ms/step - loss: 0.0024 - val_loss: 0.0062
# Epoch 35/100
# 12/12 [==============================] - 3s 224ms/step - loss: 0.0024 - val_loss: 0.0061
# Epoch 36/100
# 12/12 [==============================] - 2s 204ms/step - loss: 0.0025 - val_loss: 0.0065
# Epoch 37/100
# 12/12 [==============================] - 2s 204ms/step - loss: 0.0020 - val_loss: 0.0061
# Epoch 38/100
# 12/12 [==============================] - 2s 205ms/step - loss: 0.0019 - val_loss: 0.0058
# Epoch 39/100
# 12/12 [==============================] - 2s 206ms/step - loss: 0.0020 - val_loss: 0.0052
# Epoch 40/100
# 12/12 [==============================] - 2s 204ms/step - loss: 0.0019 - val_loss: 0.0062
# Epoch 41/100
# 12/12 [==============================] - 2s 201ms/step - loss: 0.0023 - val_loss: 0.0053
# Epoch 42/100
# 12/12 [==============================] - 2s 204ms/step - loss: 0.0022 - val_loss: 0.0054
# Epoch 43/100
# 12/12 [==============================] - 2s 208ms/step - loss: 0.0020 - val_loss: 0.0051
# Epoch 44/100
# 12/12 [==============================] - 2s 201ms/step - loss: 0.0020 - val_loss: 0.0052
# Epoch 45/100
# 12/12 [==============================] - 2s 208ms/step - loss: 0.0019 - val_loss: 0.0050
# Epoch 46/100
# 12/12 [==============================] - 2s 207ms/step - loss: 0.0016 - val_loss: 0.0048
# Epoch 47/100
# 12/12 [==============================] - 2s 208ms/step - loss: 0.0017 - val_loss: 0.0048
# Epoch 48/100
# 12/12 [==============================] - 3s 214ms/step - loss: 0.0019 - val_loss: 0.0047
# Epoch 49/100
# 12/12 [==============================] - 3s 219ms/step - loss: 0.0017 - val_loss: 0.0046
# Epoch 50/100
# 12/12 [==============================] - 3s 214ms/step - loss: 0.0017 - val_loss: 0.0046
# Epoch 51/100
# 12/12 [==============================] - 3s 213ms/step - loss: 0.0019 - val_loss: 0.0054
# Epoch 52/100
# 12/12 [==============================] - 2s 207ms/step - loss: 0.0023 - val_loss: 0.0050
# Epoch 53/100
# 12/12 [==============================] - 3s 212ms/step - loss: 0.0022 - val_loss: 0.0053
# Epoch 54/100
# 12/12 [==============================] - 3s 211ms/step - loss: 0.0016 - val_loss: 0.0052
# Epoch 55/100
# 12/12 [==============================] - 2s 204ms/step - loss: 0.0018 - val_loss: 0.0044
# Epoch 56/100
# 12/12 [==============================] - 3s 213ms/step - loss: 0.0015 - val_loss: 0.0045
# Epoch 57/100
# 12/12 [==============================] - 3s 214ms/step - loss: 0.0017 - val_loss: 0.0047
# Epoch 58/100
# 12/12 [==============================] - 3s 216ms/step - loss: 0.0016 - val_loss: 0.0046
# Epoch 59/100
# 12/12 [==============================] - 3s 217ms/step - loss: 0.0014 - val_loss: 0.0042
# Epoch 60/100
# 12/12 [==============================] - 2s 210ms/step - loss: 0.0019 - val_loss: 0.0043
# Epoch 61/100
# 12/12 [==============================] - 3s 233ms/step - loss: 0.0014 - val_loss: 0.0042
# Epoch 62/100
# 12/12 [==============================] - 3s 213ms/step - loss: 0.0017 - val_loss: 0.0040
# Epoch 63/100
# 12/12 [==============================] - 3s 215ms/step - loss: 0.0016 - val_loss: 0.0040
# Epoch 64/100
# 12/12 [==============================] - 2s 210ms/step - loss: 0.0015 - val_loss: 0.0045
# Epoch 65/100
# 12/12 [==============================] - 2s 207ms/step - loss: 0.0018 - val_loss: 0.0045
# Epoch 66/100
# 12/12 [==============================] - 2s 205ms/step - loss: 0.0018 - val_loss: 0.0042
# Epoch 67/100
# 12/12 [==============================] - 3s 219ms/step - loss: 0.0014 - val_loss: 0.0043
# Epoch 68/100
# 12/12 [==============================] - 3s 236ms/step - loss: 0.0015 - val_loss: 0.0039
# Epoch 69/100
# 12/12 [==============================] - 3s 259ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 70/100
# 12/12 [==============================] - 3s 238ms/step - loss: 0.0016 - val_loss: 0.0039
# Epoch 71/100
# 12/12 [==============================] - 3s 257ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 72/100
# 12/12 [==============================] - 3s 216ms/step - loss: 0.0014 - val_loss: 0.0035
# Epoch 73/100
# 12/12 [==============================] - 3s 232ms/step - loss: 0.0015 - val_loss: 0.0038
# Epoch 74/100
# 12/12 [==============================] - 2s 210ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 75/100
# 12/12 [==============================] - 2s 207ms/step - loss: 0.0015 - val_loss: 0.0037
# Epoch 76/100
# 12/12 [==============================] - 2s 205ms/step - loss: 0.0015 - val_loss: 0.0037
# Epoch 77/100
# 12/12 [==============================] - 2s 205ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 78/100
# 12/12 [==============================] - 2s 207ms/step - loss: 0.0015 - val_loss: 0.0038
# Epoch 79/100
# 12/12 [==============================] - 2s 204ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 80/100
# 12/12 [==============================] - 2s 203ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 81/100
# 12/12 [==============================] - 2s 204ms/step - loss: 0.0016 - val_loss: 0.0034
# Epoch 82/100
# 12/12 [==============================] - 3s 215ms/step - loss: 0.0014 - val_loss: 0.0035
# Epoch 83/100
# 12/12 [==============================] - 3s 210ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 84/100
# 12/12 [==============================] - 2s 208ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 85/100
# 12/12 [==============================] - 2s 206ms/step - loss: 0.0014 - val_loss: 0.0036
# Epoch 86/100
# 12/12 [==============================] - 3s 224ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 87/100
# 12/12 [==============================] - 2s 203ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 88/100
# 12/12 [==============================] - 2s 200ms/step - loss: 0.0013 - val_loss: 0.0035
# Epoch 89/100
# 12/12 [==============================] - 2s 203ms/step - loss: 0.0014 - val_loss: 0.0035
# Epoch 90/100
# 12/12 [==============================] - 2s 204ms/step - loss: 0.0014 - val_loss: 0.0035
# Epoch 91/100
# 12/12 [==============================] - 3s 211ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 92/100
# 12/12 [==============================] - 2s 209ms/step - loss: 0.0013 - val_loss: 0.0030
# Epoch 93/100
# 12/12 [==============================] - 2s 209ms/step - loss: 0.0012 - val_loss: 0.0029
# Epoch 94/100
# 12/12 [==============================] - 2s 208ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 95/100
# 12/12 [==============================] - 2s 207ms/step - loss: 0.0011 - val_loss: 0.0037
# Epoch 96/100
# 12/12 [==============================] - 2s 209ms/step - loss: 0.0012 - val_loss: 0.0037
# Epoch 97/100
# 12/12 [==============================] - 2s 209ms/step - loss: 0.0014 - val_loss: 0.0032
# Epoch 98/100
# 12/12 [==============================] - 2s 209ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 99/100
# 12/12 [==============================] - 3s 226ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 100/100
# 12/12 [==============================] - 2s 211ms/step - loss: 0.0014 - val_loss: 0.0030

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
print(train_predict.shape, test_predict.shape)
# Out:
# (724, 1) (306, 1)

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
print(test_predict)
# Out:
# [[283.92722]
#  [276.94473]
#  [269.18692]
#  [259.15488]
#  [250.77176]
#  [243.67233]
#  [237.50302]
#  [232.43362]
#  [227.83833]
#  [224.1903 ]
#  [219.88269]
#  [215.15605]
#  [210.92142]
#  [207.7525 ]
#  [205.91982]
#  [204.75053]
#  [204.47925]
#  [204.34598]
#  [203.44684]
#  [202.38834]
#  [201.28128]
#  [200.50671]
#  [199.90213]
#  [199.339  ]
#  [199.13518]
#  [199.56746]
#  [200.47144]
#  [201.14081]
#  [201.59079]
#  [201.73589]
#  [201.23163]
#  [200.26607]
#  [199.28665]
#  [198.82481]
#  [198.95987]
#  [198.88625]
#  [197.95897]
#  [196.34221]
#  [194.38805]
#  [192.2364 ]
#  [190.07603]
#  [188.18051]
#  [187.02995]
#  [186.36232]
#  [185.91928]
#  [185.0541 ]
#  [183.61325]
#  [181.83122]
#  [179.92934]
#  [178.08041]
#  [176.45848]
#  [175.45872]
#  [175.10162]
#  [175.37605]
#  [176.49284]
#  [178.26122]
#  [180.55276]
#  [182.9946 ]
#  [185.96799]
#  [189.22583]
#  [192.2407 ]
#  [194.86751]
#  [196.37201]
#  [196.8556 ]
#  [196.32156]
#  [195.07841]
#  [193.52649]
#  [192.3346 ]
#  [191.95312]
#  [192.51134]
#  [194.028  ]
#  [195.70712]
#  [197.15526]
#  [198.17099]
#  [198.44353]
#  [198.03471]
#  [197.54202]
#  [197.25   ]
#  [197.17409]
#  [197.4501 ]
#  [198.03587]
#  [198.97818]
#  [200.54749]
#  [202.3376 ]
#  [203.84547]
#  [204.4797 ]
#  [204.14331]
#  [203.26796]
#  [202.32094]
#  [201.68228]
#  [201.63977]
#  [201.98213]
#  [202.87733]
#  [203.78166]
#  [204.17033]
#  [204.13974]
#  [203.94711]
#  [203.46558]
#  [203.0612 ]
#  [202.90045]
#  [202.94096]
#  [203.10056]
#  [203.27818]
#  [203.40656]
#  [203.654  ]
#  [204.09468]
#  [205.16197]
#  [206.65314]
#  [207.93182]
#  [208.55081]
#  [208.64505]
#  [208.52219]
#  [208.20973]
#  [208.02051]
#  [208.21481]
#  [209.1565 ]
#  [210.80132]
#  [213.1978 ]
#  [216.60289]
#  [219.60945]
#  [222.09587]
#  [223.82079]
#  [224.57607]
#  [224.07951]
#  [222.7933 ]
#  [220.94388]
#  [218.34225]
#  [215.60919]
#  [213.45248]
#  [211.82007]
#  [210.77748]
#  [210.13565]
#  [209.60628]
#  [208.94058]
#  [207.75597]
#  [206.21123]
#  [204.44035]
#  [202.2744 ]
#  [200.25061]
#  [198.902  ]
#  [198.18178]
#  [197.96527]
#  [198.35336]
#  [199.09433]
#  [200.1126 ]
#  [201.17561]
#  [202.16005]
#  [203.37555]
#  [204.78722]
#  [206.03456]
#  [207.22224]
#  [207.85716]
#  [208.09587]
#  [208.57866]
#  [209.33488]
#  [210.28409]
#  [211.24226]
#  [212.04317]
#  [212.22963]
#  [211.7143 ]
#  [210.47252]
#  [208.71948]
#  [206.84349]
#  [205.53093]
#  [205.44109]
#  [206.59566]
#  [209.32912]
#  [213.16188]
#  [217.34871]
#  [222.10495]
#  [227.12268]
#  [231.18457]
#  [234.063  ]
#  [236.66272]
#  [240.0819 ]
#  [242.98486]
#  [245.16588]
#  [246.20807]
#  [246.72513]
#  [246.91318]
#  [247.13737]
#  [247.35898]
#  [247.89174]
#  [248.57224]
#  [250.09389]
#  [252.89972]
#  [257.048  ]
#  [261.96405]
#  [266.56424]
#  [270.05975]
#  [272.5166 ]
#  [274.18906]
#  [274.81833]
#  [274.49826]
#  [273.4294 ]
#  [272.4292 ]
#  [270.06158]
#  [267.0736 ]
#  [264.68683]
#  [263.6165 ]
#  [264.57236]
#  [267.2984 ]
#  [270.79984]
#  [273.9758 ]
#  [276.7761 ]
#  [279.1531 ]
#  [281.03195]
#  [282.70908]
#  [284.4137 ]
#  [285.7753 ]
#  [286.2459 ]
#  [287.1126 ]
#  [290.13312]
#  [294.7275 ]
#  [299.2446 ]
#  [301.47992]
#  [301.98453]
#  [301.89227]
#  [300.67126]
#  [297.42883]
#  [292.8558 ]
#  [287.55988]
#  [283.3212 ]
#  [280.6098 ]
#  [282.56467]
#  [291.1891 ]
#  [304.70508]
#  [322.55524]
#  [347.71637]
#  [375.8286 ]
#  [399.15573]
#  [412.1303 ]
#  [414.1708 ]
#  [409.60254]
#  [405.5719 ]
#  [402.35098]
#  [402.2422 ]
#  [405.05627]
#  [405.41565]
#  [401.17276]
#  [396.10983]
#  [394.40353]
#  [396.01498]
#  [395.70352]
#  [394.5871 ]
#  [393.1996 ]
#  [394.40228]
#  [395.4061 ]
#  [393.11478]
#  [390.07196]
#  [387.08307]
#  [384.86215]
#  [382.29535]
#  [380.41565]
#  [378.3942 ]
#  [374.5308 ]
#  [369.83594]
#  [366.3914 ]
#  [363.90848]
#  [363.52643]
#  [362.3668 ]
#  [359.6781 ]
#  [356.75134]
#  [355.03186]
#  [355.26022]
#  [358.02008]
#  [358.93384]
#  [357.28152]
#  [355.58502]
#  [354.03476]
#  [352.44815]
#  [346.9926 ]
#  [341.49158]
#  [337.65305]
#  [335.35992]
#  [333.06577]
#  [330.63416]
#  [329.5513 ]
#  [329.76215]
#  [332.05222]
#  [336.9697 ]
#  [344.81467]
#  [352.73743]
#  [357.7249 ]
#  [358.8413 ]
#  [357.30295]
#  [355.23294]
#  [353.5152 ]
#  [352.90115]
#  [353.79944]
#  [356.10953]
#  [359.48743]
#  [361.56415]
#  [366.34177]
#  [372.57755]
#  [378.9098 ]
#  [383.88675]
#  [390.33932]
#  [399.3934 ]
#  [408.6027 ]
#  [415.8256 ]
#  [422.6889 ]
#  [427.19415]
#  [429.4223 ]
#  [431.71497]
#  [434.95642]]

# %%
X = scaler.fit_transform(np.array(close).reshape(-1,1))

# %%
import matplotlib.pyplot as plt

look_back=100
trainPredictPlot = np.empty_like(X)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = np.empty_like(X)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(X)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(X))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
